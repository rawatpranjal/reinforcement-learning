# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import beta
plt.rcParams["figure.figsize"]=(30,10)
plt.rcParams['font.size']=20

# %%
# K-arms with Beta Distribution
# E(X) = a/(a+b)
b = 40
K = 10
actual_means = np.linspace(0.1,0.9,K)
for i in range(K):
    a = actual_means[i]*b/(1-actual_means[i]) # reverse engineer α
    plt.hist(np.random.beta(5/(1-actual_means[i]), 5, 1000), bins = 30)
    plt.title(f'Mean: {a/(a+b)}')
    plt.show()

# %%
def printCI(mean_vec, times_vec, δ=0.95, K=3, ρ=0.2):
    for i in range(K):
        plt.scatter(i, mean_vec[i],c='r')
        plt.scatter(i, mean_vec[i]+ρ*np.power(np.log(np.sum(np.round(times_vec)))/(2*times_vec[i]),0.5), c='b')
        plt.scatter(i, mean_vec[i]-ρ*np.power(np.log(np.sum(np.round(times_vec)))/(2*times_vec[i]),0.5), c='g')

def scoreUAB(mean_vec, times_vec, ρ=0.2):
    return np.argmax(mean_vec+ρ*np.power(np.log(np.sum(np.round(times_vec)))/(2*times_vec),0.5))
    
def generateReward(i, actual_means, b=5):
    a = actual_means[i]*b/(1-actual_means[i])
    return np.random.beta(a, b) 

# UAB Algorithm
N = 50
K = 10
actual_means = np.linspace(0.1,0.9,K)
est_means = 0.5*np.ones(K)
times = 0.1*np.ones(K)
b = 5
choices = []
for t in range(1, N+1):
    i = scoreUAB(est_means, times) # score and choose
    x = generateReward(i, actual_means, b = 5) # generate reward
    est_means[i] = (t-1)*est_means[i]/t + (1/t)*x # update mean
    times[i] = np.round(times[i] + 1) # updates times visited
    printCI(est_means, times, K=K)
    choices.append(i)
    print(f'Period {t}, Choice: {i}, Reward: {x}, EstMean: {est_means[i]}, TimesVisited: {times[i]}')
plt.ylim([0,1])
plt.show()
# Out:
# /var/folders/xt/r947d5fd2yz1_fkptq29sn8r0000gn/T/ipykernel_3346/4032770774.py:8: RuntimeWarning: divide by zero encountered in log
#   return np.argmax(mean_vec+ρ*np.power(np.log(np.sum(np.round(times_vec)))/(2*times_vec),0.5))
# Period 1, Choice: 0, Reward: 0.025149524824723154, EstMean: 0.025149524824723154, TimesVisited: 1.0
# Period 2, Choice: 1, Reward: 0.08250301239158525, EstMean: 0.29125150619579265, TimesVisited: 1.0
# Period 3, Choice: 2, Reward: 0.03136324629221978, EstMean: 0.34378774876407325, TimesVisited: 1.0
# Period 4, Choice: 3, Reward: 0.23248645881251107, EstMean: 0.43312161470312777, TimesVisited: 1.0
# Period 5, Choice: 4, Reward: 0.4077868291380372, EstMean: 0.48155736582760744, TimesVisited: 1.0
# Period 6, Choice: 5, Reward: 0.6673605086387128, EstMean: 0.5278934181064522, TimesVisited: 1.0
# Period 7, Choice: 6, Reward: 0.6655682176636882, EstMean: 0.523652602523384, TimesVisited: 1.0
# Period 8, Choice: 7, Reward: 0.6983453442029983, EstMean: 0.5247931680253748, TimesVisited: 1.0
# Period 9, Choice: 8, Reward: 0.8331465225779504, EstMean: 0.5370162802864389, TimesVisited: 1.0
# Period 10, Choice: 9, Reward: 0.9351692641426446, EstMean: 0.5435169264142645, TimesVisited: 1.0
# Period 11, Choice: 9, Reward: 0.8618503865966147, EstMean: 0.5724563318853874, TimesVisited: 2.0
# Period 12, Choice: 8, Reward: 0.7636194258004325, EstMean: 0.5558998757459384, TimesVisited: 2.0
# Period 13, Choice: 5, Reward: 0.4924096866842361, EstMean: 0.5251639003047432, TimesVisited: 2.0
# Period 14, Choice: 7, Reward: 0.7439272788918347, EstMean: 0.5404456045158362, TimesVisited: 2.0
# Period 15, Choice: 6, Reward: 0.5142659196288574, EstMean: 0.5230268236637489, TimesVisited: 2.0
# Period 16, Choice: 9, Reward: 0.8623669526626551, EstMean: 0.5905757456839665, TimesVisited: 3.0
# Period 17, Choice: 9, Reward: 0.8716668791160004, EstMean: 0.607110518238792, TimesVisited: 4.0
# Period 18, Choice: 9, Reward: 0.9033125648000668, EstMean: 0.6235661874921963, TimesVisited: 5.0
# Period 19, Choice: 9, Reward: 0.9022704689495215, EstMean: 0.638234833884687, TimesVisited: 6.0
# Period 20, Choice: 9, Reward: 0.8211311774843973, EstMean: 0.6473796510646725, TimesVisited: 7.0
# Period 21, Choice: 9, Reward: 0.7819752210867674, EstMean: 0.6537889639228674, TimesVisited: 8.0
# Period 22, Choice: 9, Reward: 0.8996739056969048, EstMean: 0.6649655521853236, TimesVisited: 9.0
# Period 23, Choice: 9, Reward: 0.9194948142717185, EstMean: 0.6760320418412539, TimesVisited: 10.0
# Period 24, Choice: 9, Reward: 0.9479102473850903, EstMean: 0.6873603004055804, TimesVisited: 11.0
# Period 25, Choice: 9, Reward: 0.933927206871706, EstMean: 0.6972229766642254, TimesVisited: 12.0
# Period 26, Choice: 9, Reward: 0.9203954523830729, EstMean: 0.7058065334226425, TimesVisited: 13.0
# Period 27, Choice: 9, Reward: 0.9128509858167794, EstMean: 0.7134748464742772, TimesVisited: 14.0
# Period 28, Choice: 9, Reward: 0.879757489574413, EstMean: 0.7194135122992821, TimesVisited: 15.0
# Period 29, Choice: 9, Reward: 0.8413936344563053, EstMean: 0.723619723408145, TimesVisited: 16.0
# Period 30, Choice: 9, Reward: 0.8994666163473971, EstMean: 0.7294812865061201, TimesVisited: 17.0
# Period 31, Choice: 9, Reward: 0.89523640003547, EstMean: 0.7348282256522282, TimesVisited: 18.0
# Period 32, Choice: 9, Reward: 0.8913807625044116, EstMean: 0.7397204924288588, TimesVisited: 19.0
# Period 33, Choice: 9, Reward: 0.9198684084280389, EstMean: 0.7451795201864098, TimesVisited: 20.0
# Period 34, Choice: 9, Reward: 0.8920452177425902, EstMean: 0.7494990995262975, TimesVisited: 21.0
# Period 35, Choice: 9, Reward: 0.9349826625565838, EstMean: 0.7547986298985913, TimesVisited: 22.0
# Period 36, Choice: 9, Reward: 0.8809543631462351, EstMean: 0.7583029558221369, TimesVisited: 23.0
# Period 37, Choice: 9, Reward: 0.9684907352214234, EstMean: 0.7639837066167122, TimesVisited: 24.0
# Period 38, Choice: 9, Reward: 0.865821519229132, EstMean: 0.7666636490538812, TimesVisited: 25.0
# Period 39, Choice: 9, Reward: 0.9349405196910229, EstMean: 0.7709784406086796, TimesVisited: 26.0
# Period 40, Choice: 9, Reward: 0.8968887421771449, EstMean: 0.7741261981478912, TimesVisited: 27.0
# Period 41, Choice: 9, Reward: 0.9430200770996247, EstMean: 0.778245561049153, TimesVisited: 28.0
# Period 42, Choice: 9, Reward: 0.9250797445961035, EstMean: 0.7817416130383661, TimesVisited: 29.0
# Period 43, Choice: 9, Reward: 0.8622405307841321, EstMean: 0.7836136808929188, TimesVisited: 30.0
# Period 44, Choice: 9, Reward: 0.8860141431308641, EstMean: 0.7859409641255994, TimesVisited: 31.0
# Period 45, Choice: 9, Reward: 0.8223824497147149, EstMean: 0.7867507749164687, TimesVisited: 32.0
# Period 46, Choice: 9, Reward: 0.9048169628998363, EstMean: 0.7893174311769767, TimesVisited: 33.0
# Period 47, Choice: 9, Reward: 0.9392879202751745, EstMean: 0.7925082926471512, TimesVisited: 34.0
# Period 48, Choice: 9, Reward: 0.9227932992874116, EstMean: 0.7952225636188233, TimesVisited: 35.0
# Period 49, Choice: 9, Reward: 0.8794909521069082, EstMean: 0.7969423266491923, TimesVisited: 36.0
# Period 50, Choice: 9, Reward: 0.9030564594392294, EstMean: 0.7990646093049929, TimesVisited: 37.0

# %%
plt.scatter(range(N), choices)

# %%
# Regret
def regret(n, actual_means, choices):
    left = np.max(actual_means)*n
    right = 0
    for i in choices[0:n]:
        right += actual_means[i]
    return left - right

for n in range(N):
    plt.scatter(n, regret(n, actual_means, choices))
plt.title('Regret')
plt.show()
