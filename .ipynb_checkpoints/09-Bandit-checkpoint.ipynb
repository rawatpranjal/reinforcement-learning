# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import beta
plt.rcParams["figure.figsize"] = (30, 10)
plt.rcParams['font.size']=20

# %%
# K-arms with Beta Distribution
# E(X) = a/(a+b)
b = 40
K = 10
actual_means = np.linspace(0.1,0.9,K)
for i in range(K):
    a = actual_means[i]*b/(1-actual_means[i]) # reverse engineer α
    plt.hist(np.random.beta(5/(1-actual_means[i]), 5, 1000), bins = 30)
    plt.title(f'Mean: {a/(a+b)}')
    plt.show()

# %%
def bound(δ,n):
    return np.power(np.log(2/δ)/(2*n),0.5)

def printCI(mean_vec, times_vec, δ=0.95, K=3):
    for i in range(K):
        plt.scatter(i, mean_vec[i],c='r')
        plt.scatter(i, mean_vec[i]+bound(δ,times_vec[i]), c='b')
        plt.scatter(i, mean_vec[i]-bound(δ,times_vec[i]), c='g')

def scoreUAB(mean_vec, times_vec, δ=0.95):
    return np.argmax(mean_vec+bound(δ,times_vec))
    
def generateReward(i, actual_means, b=5):
    a = actual_means[i]*b/(1-actual_means[i])
    return np.random.beta(a, b) 

# UAB Algorithm
N = 50
K = 10
actual_means = np.linspace(0.1,0.9,K)
est_means = 0.5*np.ones(K)
times = 0.1*np.ones(K)
b = 5
choices = []
for t in range(1, N+1):
    i = scoreUAB(est_means, times, δ=0.95) # score and choose
    x = generateReward(i, actual_means, b = 5) # generate reward
    est_means[i] = (t-1)*est_means[i]/t + (1/t)*x # update mean
    times[i] = np.round(times[i] + 1) # updates times visited
    printCI(est_means, times, K=K)
    choices.append(i)
    print(f'Period {t}, Choice: {i}, Reward: {x}, EstMean: {est_means[i]}, TimesVisited: {times[i]}')
plt.ylim([0,1])
plt.show()
# Out:
# Period 1, Choice: 0, Reward: 0.012964088867231134, EstMean: 0.012964088867231134, TimesVisited: 1.0
# Period 2, Choice: 1, Reward: 0.03245622889214358, EstMean: 0.2662281144460718, TimesVisited: 1.0
# Period 3, Choice: 2, Reward: 0.3020355386999287, EstMean: 0.4340118462333096, TimesVisited: 1.0
# Period 4, Choice: 3, Reward: 0.365026413553018, EstMean: 0.4662566033882545, TimesVisited: 1.0
# Period 5, Choice: 4, Reward: 0.3732161249030735, EstMean: 0.47464322498061473, TimesVisited: 1.0
# Period 6, Choice: 5, Reward: 0.6429781911731053, EstMean: 0.5238296985288509, TimesVisited: 1.0
# Period 7, Choice: 6, Reward: 0.5894644330399142, EstMean: 0.5127806332914163, TimesVisited: 1.0
# Period 8, Choice: 7, Reward: 0.6490676570481473, EstMean: 0.5186334571310184, TimesVisited: 1.0
# Period 9, Choice: 8, Reward: 0.8141892807515319, EstMean: 0.5349099200835035, TimesVisited: 1.0
# Period 10, Choice: 9, Reward: 0.9397684432533369, EstMean: 0.5439768443253337, TimesVisited: 1.0
# Period 11, Choice: 9, Reward: 0.9035460430011122, EstMean: 0.576664953295859, TimesVisited: 2.0
# Period 12, Choice: 8, Reward: 0.8088276545660237, EstMean: 0.5577363979570468, TimesVisited: 2.0
# Period 13, Choice: 5, Reward: 0.3890582627610373, EstMean: 0.5134626650082499, TimesVisited: 2.0
# Period 14, Choice: 7, Reward: 0.8465337326531709, EstMean: 0.5420549053826007, TimesVisited: 2.0
# Period 15, Choice: 6, Reward: 0.7303665344478151, EstMean: 0.5272863600351763, TimesVisited: 2.0
# Period 16, Choice: 4, Reward: 0.5332456802644929, EstMean: 0.4783058784358571, TimesVisited: 2.0
# Period 17, Choice: 3, Reward: 0.3172984851638473, EstMean: 0.45749436113975994, TimesVisited: 2.0
# Period 18, Choice: 2, Reward: 0.5239217293488792, EstMean: 0.4390068397397301, TimesVisited: 2.0
# Period 19, Choice: 9, Reward: 0.9068151236062395, EstMean: 0.594041278049037, TimesVisited: 3.0
# Period 20, Choice: 8, Reward: 0.9244634550672125, EstMean: 0.576072750812555, TimesVisited: 3.0
# Period 21, Choice: 7, Reward: 0.653808994228017, EstMean: 0.5473765286609539, TimesVisited: 3.0
# Period 22, Choice: 6, Reward: 0.6203486103723571, EstMean: 0.5315164623232299, TimesVisited: 3.0
# Period 23, Choice: 9, Reward: 0.9085310358238321, EstMean: 0.6077147457783759, TimesVisited: 4.0
# Period 24, Choice: 5, Reward: 0.6136386853349277, EstMean: 0.5176366658551947, TimesVisited: 3.0
# Period 25, Choice: 8, Reward: 0.8011509776853573, EstMean: 0.5850758798874671, TimesVisited: 4.0
# Period 26, Choice: 9, Reward: 0.9267955903665153, EstMean: 0.6199870859548429, TimesVisited: 5.0
# Period 27, Choice: 4, Reward: 0.4066008598215883, EstMean: 0.47565013700569897, TimesVisited: 3.0
# Period 28, Choice: 7, Reward: 0.7397892203787487, EstMean: 0.554248410508018, TimesVisited: 4.0
# Period 29, Choice: 9, Reward: 0.9032169503801585, EstMean: 0.6297536330039917, TimesVisited: 6.0
# Period 30, Choice: 8, Reward: 0.9051143584982494, EstMean: 0.5957438291744932, TimesVisited: 5.0
# Period 31, Choice: 3, Reward: 0.7293655397417913, EstMean: 0.4662643991591803, TimesVisited: 3.0
# Period 32, Choice: 6, Reward: 0.5171955738544569, EstMean: 0.5310689345585808, TimesVisited: 4.0
# Period 33, Choice: 9, Reward: 0.8969455332576323, EstMean: 0.637850357254102, TimesVisited: 7.0
# Period 34, Choice: 1, Reward: 0.11972786997030585, EstMean: 0.26191928372619633, TimesVisited: 2.0
# Period 35, Choice: 2, Reward: 0.08925112420011828, EstMean: 0.42901381929574117, TimesVisited: 3.0
# Period 36, Choice: 5, Reward: 0.37512299490622986, EstMean: 0.5136779527732791, TimesVisited: 4.0
# Period 37, Choice: 8, Reward: 0.8415916594332287, EstMean: 0.602388365127432, TimesVisited: 6.0
# Period 38, Choice: 9, Reward: 0.8974258009699281, EstMean: 0.6446812899834659, TimesVisited: 8.0
# Period 39, Choice: 9, Reward: 0.920614373749721, EstMean: 0.6517564972595236, TimesVisited: 9.0
# Period 40, Choice: 7, Reward: 0.9403499179344883, EstMean: 0.5639009481936798, TimesVisited: 5.0
# Period 41, Choice: 9, Reward: 0.9166383680376369, EstMean: 0.6582170306931361, TimesVisited: 10.0
# Period 42, Choice: 8, Reward: 0.8636240645337606, EstMean: 0.6086082627323446, TimesVisited: 7.0
# Period 43, Choice: 9, Reward: 0.8781336717823313, EstMean: 0.6633313711835824, TimesVisited: 11.0
# Period 44, Choice: 9, Reward: 0.9143981688806456, EstMean: 0.6690374347676066, TimesVisited: 12.0
# Period 45, Choice: 9, Reward: 0.9448277751963281, EstMean: 0.6751661089993559, TimesVisited: 13.0
# Period 46, Choice: 9, Reward: 0.8479358283053386, EstMean: 0.6789219724625295, TimesVisited: 14.0
# Period 47, Choice: 9, Reward: 0.8878270439325722, EstMean: 0.6833667612172113, TimesVisited: 15.0
# Period 48, Choice: 9, Reward: 0.8366941334406737, EstMean: 0.6865610814718668, TimesVisited: 16.0
# Period 49, Choice: 8, Reward: 0.9014501559885566, EstMean: 0.6145846279008387, TimesVisited: 8.0
# Period 50, Choice: 9, Reward: 0.8460395968358297, EstMean: 0.689750651779146, TimesVisited: 17.0

# %%
plt.scatter(range(N), choices)

# %%
# Regret
def regret(n, actual_means, choices):
    left = np.max(actual_means)*n
    right = 0
    for i in choices[0:n]:
        right += actual_means[i]
    return left - right

for n in range(N):
    plt.scatter(n, regret(n, actual_means, choices))
plt.title('Regret')
plt.show()
